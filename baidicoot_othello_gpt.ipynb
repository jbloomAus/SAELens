# %%
import importlib
import transformer_lens
importlib.reload(transformer_lens)
from transformer_lens import HookedTransformer, HookedTransformerConfig
from transformer_lens.train import HookedTransformerTrainConfig, train
from datasets import Dataset
import numpy as np
import torch as t
import os
from sae_lens import LanguageModelSAERunnerConfig, SAETrainingRunner

device = t.device("cuda" if t.cuda.is_available() else "cpu")

# %%
total_training_steps = 30_000  # probably we should do more
batch_size = 4096
total_training_tokens = total_training_steps * batch_size

lr_warm_up_steps = 0
lr_decay_steps = total_training_steps // 5  # 20% of training
l1_warm_up_steps = total_training_steps // 20  # 5% of training

cfg = LanguageModelSAERunnerConfig(
    # Data Generating Function (Model + Training Distibuion)
    model_name="Baidicoot/Othello-GPT-Transformer-Lens",  # added this to offical list in TransformerLens library
    hook_name="blocks.0.hook_mlp_out",  # A valid hook point (see more details here: https://neelnanda-io.github.io/TransformerLens/generated/demos/Main_Demo.html#Hook-Points)
    hook_layer=0,  # Only one layer in the model.
    d_in=128*4,  # the width of the mlp output.
    dataset_path="Thijmen/othello_dataset",  # my own dataset which i created in this file and uploaded to HF.
    is_dataset_tokenized=True, # dataset is tokenized, although i saw this flag is not in use anymore
    streaming=False,  # we could pre-download the token dataset if it was small.
    prepend_bos=False, # set this to false
    # SAE Parameters
    mse_loss_normalization=None,  # We won't normalize the mse loss,
    expansion_factor=1,  # the width of the SAE. Larger will result in better stats but slower training.
    b_dec_init_method="zeros",  # The geometric median can be used to initialize the decoder weights.
    apply_b_dec_to_input=False,  # We won't apply the decoder weights to the input.
    normalize_sae_decoder=False,
    scale_sparsity_penalty_by_decoder_norm=True,
    decoder_heuristic_init=True,
    init_encoder_as_decoder_transpose=True,
    normalize_activations=True,
    # Training Parameters
    lr=5e-5,  # lower the better, we'll go fairly high to speed up the tutorial.
    adam_beta1=0.9,  # adam params (default, but once upon a time we experimented with these.)
    adam_beta2=0.999,
    lr_scheduler_name="constant",  # constant learning rate with warmup. Could be better schedules out there.
    lr_warm_up_steps=lr_warm_up_steps,  # this can help avoid too many dead features initially.
    lr_decay_steps=lr_decay_steps,  # this will help us avoid overfitting.
    l1_coefficient=5,  # will control how sparse the feature activations are
    l1_warm_up_steps=l1_warm_up_steps,  # this can help avoid too many dead features initially.
    lp_norm=1.0,  # the L1 penalty (and not a Lp for p < 1)
    train_batch_size_tokens=batch_size,
    context_size=3,  # will control the lenght of the prompts we feed to the model. Larger is better but slower. so for the tutorial we'll use a short one.
    # Activation Store Parameters
    n_batches_in_buffer=64,  # controls how many activations we store / shuffle.
    training_tokens=total_training_tokens,  # 100 million tokens is quite a few, but we want to see good stats. Get a coffee, come back.
    store_batch_size_prompts=16,
    # Resampling protocol
    use_ghost_grads=False,  # we don't use ghost grads anymore.
    feature_sampling_window=1000,  # this controls our reporting of feature sparsity stats
    dead_feature_window=1000,  # would effect resampling or ghost grads if we were using it.
    dead_feature_threshold=1e-4,  # would effect resampling or ghost grads if we were using it.
    # WANDB
    log_to_wandb=False,  # always use wandb unless you are just testing code.
    wandb_project="sae_lens_tutorial",
    wandb_log_frequency=30,
    eval_every_n_wandb_logs=20,
    # Misc
    device=device,
    seed=42,
    n_checkpoints=0,
    checkpoint_path="checkpoints",
    dtype="float32"
)
# look at the next cell to see some instruction for what to do while this is running.
sparse_autoencoder = SAETrainingRunner(cfg).run()
# Out:
# Run name: 512-L1-5-LR-5e-05-Tokens-1.229e+08
# n_tokens_per_buffer (millions): 0.003072
# Lower bound: n_contexts_per_buffer (millions): 0.001024
# Total training steps: 30000
# Total wandb updates: 1000
# n_tokens_per_feature_sampling_window (millions): 12.288
# n_tokens_per_dead_feature_window (millions): 12.288
# We will reset the sparsity calculation 30 times.
# Number tokens in sparsity calculation window: 4.10e+06
# Loaded pretrained model Baidicoot/Othello-GPT-Transformer-Lens into HookedTransformer
# Estimating norm scaling factor: 100%|██████████| 1000/1000 [02:44<00:00,  6.09it/s]
# interrupted, saving progress
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# File /mnt/c/Users/thijm/GitHub/Master_related/ProjectAI_related/OthelloGPT-SAELens/sae_lens/training/activations_store.py:517, in ActivationsStore.next_batch(self)
#     515 try:
#     516     # Try to get the next batch
# --> 517     return next(self.dataloader)
#     518 except StopIteration:
#     519     # If the DataLoader is exhausted, create a new one
#
# File /mnt/c/Users/thijm/GitHub/Master_related/ProjectAI_related/OthelloGPT-SAELens/.venv/lib/python3.11/site-packages/torch/utils/data/dataloader.py:631, in _BaseDataLoaderIter.__next__(self)
#     630     self._reset()  # type: ignore[call-arg]
# --> 631 data = self._next_data()
#     632 self._num_yielded += 1
#
# File /mnt/c/Users/thijm/GitHub/Master_related/ProjectAI_related/OthelloGPT-SAELens/.venv/lib/python3.11/site-packages/torch/utils/data/dataloader.py:674, in _SingleProcessDataLoaderIter._next_data(self)
#     673 def _next_data(self):
# --> 674     index = self._next_index()  # may raise StopIteration
#     675     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#
# File /mnt/c/Users/thijm/GitHub/Master_related/ProjectAI_related/OthelloGPT-SAELens/.venv/lib/python3.11/site-packages/torch/utils/data/dataloader.py:621, in _BaseDataLoaderIter._next_index(self)
#     620 def _next_index(self):
# --> 621     return next(self._sampler_iter)
#
# StopIteration:
#
# During handling of the above exception, another exception occurred:
#
# InterruptedException                      Traceback (most recent call last)
# File /mnt/c/Users/thijm/GitHub/Master_related/ProjectAI_related/OthelloGPT-SAELens/sae_lens/sae_training_runner.py:130, in SAETrainingRunner.run_trainer_with_interruption_handling(self, trainer)
#     129     # train SAE
# --> 130     sae = trainer.fit()
#     132 except (KeyboardInterrupt, InterruptedException):
#
# File /mnt/c/Users/thijm/GitHub/Master_related/ProjectAI_related/OthelloGPT-SAELens/sae_lens/training/sae_trainer.py:159, in SAETrainer.fit(self)
#     157 while self.n_training_tokens < self.cfg.total_training_tokens:
#     158     # Do a training step.
# --> 159     layer_acts = self.activation_store.next_batch()[:, 0, :]
#     160     self.n_training_tokens += self.cfg.train_batch_size_tokens
#
# File /mnt/c/Users/thijm/GitHub/Master_related/ProjectAI_related/OthelloGPT-SAELens/sae_lens/training/activations_store.py:520, in ActivationsStore.next_batch(self)
#     518 except StopIteration:
#     519     # If the DataLoader is exhausted, create a new one
# --> 520     self._dataloader = self.get_data_loader()
#     521     return next(self.dataloader)
#
# File /mnt/c/Users/thijm/GitHub/Master_related/ProjectAI_related/OthelloGPT-SAELens/sae_lens/training/activations_store.py:489, in ActivationsStore.get_data_loader(self)
#     487 # 1. # create new buffer by mixing stored and new buffer
#     488 mixing_buffer = torch.cat(
# --> 489     [self.get_buffer(self.n_batches_in_buffer // 2), self.storage_buffer],
#     490     dim=0,
#     491 )
#     493 mixing_buffer = mixing_buffer[torch.randperm(mixing_buffer.shape[0])]
#
# File /mnt/c/Users/thijm/GitHub/Master_related/ProjectAI_related/OthelloGPT-SAELens/sae_lens/training/activations_store.py:442, in ActivationsStore.get_buffer(self, n_batches_in_buffer)
#     440 for refill_batch_idx_start in refill_iterator:
#     441     # move batch toks to gpu for model
# --> 442     refill_batch_tokens = self.get_batch_tokens().to(self.model.cfg.device)
#     443     refill_activations = self.get_activations(refill_batch_tokens)
#
# File /mnt/c/Users/thijm/GitHub/Master_related/ProjectAI_related/OthelloGPT-SAELens/sae_lens/training/activations_store.py:273, in ActivationsStore.get_batch_tokens(self, batch_size)
#     272 while batch_tokens.shape[0] < batch_size:
# --> 273     tokens = self._get_next_dataset_tokens()
#     274     token_len = tokens.shape[0]
#
# File /mnt/c/Users/thijm/GitHub/Master_related/ProjectAI_related/OthelloGPT-SAELens/sae_lens/training/activations_store.py:553, in ActivationsStore._get_next_dataset_tokens(self)
#     551 else:
#     552     tokens = torch.tensor(
# --> 553         next(self.iterable_dataset)[self.tokens_column],
#     554         dtype=torch.long,
#     555         device=device,
#     556         requires_grad=False,
#     557     )
#     558     if (
#     559         not self.prepend_bos
#     560         # and tokens[0] == self.model.tokenizer.bos_token_id  # type: ignore
#     561     ):
#
# File /mnt/c/Users/thijm/GitHub/Master_related/ProjectAI_related/OthelloGPT-SAELens/.venv/lib/python3.11/site-packages/datasets/arrow_dataset.py:2440, in Dataset.__iter__(self)
#    2439 pa_subtable_ex = pa_subtable.slice(i, 1)
# -> 2440 formatted_output = format_table(
#    2441     pa_subtable_ex,
#    2442     0,
#    2443     formatter=formatter,
#    2444     format_columns=self._format_columns,
#    2445     output_all_columns=self._output_all_columns,
#    2446 )
#    2447 yield formatted_output
#
# File /mnt/c/Users/thijm/GitHub/Master_related/ProjectAI_related/OthelloGPT-SAELens/.venv/lib/python3.11/site-packages/datasets/formatting/formatting.py:633, in format_table(table, key, formatter, format_columns, output_all_columns)
#     632 if format_columns is None:
# --> 633     return formatter(pa_table, query_type=query_type)
#     634 elif query_type == "column":
#
# File /mnt/c/Users/thijm/GitHub/Master_related/ProjectAI_related/OthelloGPT-SAELens/.venv/lib/python3.11/site-packages/datasets/formatting/formatting.py:397, in Formatter.__call__(self, pa_table, query_type)
#     396 if query_type == "row":
# --> 397     return self.format_row(pa_table)
#     398 elif query_type == "column":
#
# File /mnt/c/Users/thijm/GitHub/Master_related/ProjectAI_related/OthelloGPT-SAELens/.venv/lib/python3.11/site-packages/datasets/formatting/formatting.py:437, in PythonFormatter.format_row(self, pa_table)
#     436     return LazyRow(pa_table, self)
# --> 437 row = self.python_arrow_extractor().extract_row(pa_table)
#     438 row = self.python_features_decoder.decode_row(row)
#
# File /mnt/c/Users/thijm/GitHub/Master_related/ProjectAI_related/OthelloGPT-SAELens/.venv/lib/python3.11/site-packages/datasets/formatting/formatting.py:145, in PythonArrowExtractor.extract_row(self, pa_table)
#     144 def extract_row(self, pa_table: pa.Table) -> dict:
# --> 145     return _unnest(pa_table.to_pydict())
#
# File /mnt/c/Users/thijm/GitHub/Master_related/ProjectAI_related/OthelloGPT-SAELens/sae_lens/sae_training_runner.py:25, in interrupt_callback(sig_num, stack_frame)
#      24 def interrupt_callback(sig_num: Any, stack_frame: Any):
# ---> 25     raise InterruptedException()
#
# InterruptedException:
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 63
#       9 cfg = LanguageModelSAERunnerConfig(
#      10     # Data Generating Function (Model + Training Distibuion)
#      11     model_name="Baidicoot/Othello-GPT-Transformer-Lens",  # added this to offical list in TransformerLens library
#    (...)
#      60     dtype="float32"
#      61 )
#      62 # look at the next cell to see some instruction for what to do while this is running.
# ---> 63 sparse_autoencoder = SAETrainingRunner(cfg).run()
#
# File /mnt/c/Users/thijm/GitHub/Master_related/ProjectAI_related/OthelloGPT-SAELens/sae_lens/sae_training_runner.py:87, in SAETrainingRunner.run(self)
#      78 trainer = SAETrainer(
#      79     model=self.model,
#      80     sae=self.sae,
#    (...)
#      83     cfg=self.cfg,
#      84 )
#      86 self._compile_if_needed()
# ---> 87 sae = self.run_trainer_with_interruption_handling(trainer)
#      89 if self.cfg.log_to_wandb:
#      90     wandb.finish()
#
# File /mnt/c/Users/thijm/GitHub/Master_related/ProjectAI_related/OthelloGPT-SAELens/sae_lens/sae_training_runner.py:135, in SAETrainingRunner.run_trainer_with_interruption_handling(self, trainer)
#     133 print("interrupted, saving progress")
#     134 checkpoint_name = trainer.n_training_tokens
# --> 135 self.save_checkpoint(trainer, checkpoint_name=checkpoint_name)
#     136 print("done saving")
#     137 raise
#
# File /mnt/c/Users/thijm/GitHub/Master_related/ProjectAI_related/OthelloGPT-SAELens/sae_lens/sae_training_runner.py:177, in SAETrainingRunner.save_checkpoint(self, trainer, checkpoint_name, wandb_aliases)
#     175 if self.sae.cfg.normalize_sae_decoder:
#     176     self.sae.set_decoder_norm_to_unit_norm()
# --> 177 self.sae.save_model(path)
#     179 # let's over write the cfg file with the trainer cfg, which is a super set of the original cfg.
#     180 # and should not cause issues but give us more info about SAEs we trained in SAE Lens.
#     181 config = trainer.cfg.to_dict()
#
# File /mnt/c/Users/thijm/GitHub/Master_related/ProjectAI_related/OthelloGPT-SAELens/sae_lens/sae.py:288, in SAE.save_model(self, path, sparsity)
#     285 config = self.cfg.to_dict()
#     287 with open(f"{path}/{SAE_CFG_PATH}", "w") as f:
# --> 288     json.dump(config, f)
#     290 if sparsity is not None:
#     291     sparsity_in_dict = {"sparsity": sparsity}
#
# File ~/.pyenv/versions/3.11.0/lib/python3.11/json/__init__.py:179, in dump(obj, fp, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     173     iterable = cls(skipkeys=skipkeys, ensure_ascii=ensure_ascii,
#     174         check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     175         separators=separators,
#     176         default=default, sort_keys=sort_keys, **kw).iterencode(obj)
#     177 # could accelerate with writelines in some versions of Python, at
#     178 # a debuggability cost
# --> 179 for chunk in iterable:
#     180     fp.write(chunk)
#
# File ~/.pyenv/versions/3.11.0/lib/python3.11/json/encoder.py:432, in _make_iterencode.<locals>._iterencode(o, _current_indent_level)
#     430     yield from _iterencode_list(o, _current_indent_level)
#     431 elif isinstance(o, dict):
# --> 432     yield from _iterencode_dict(o, _current_indent_level)
#     433 else:
#     434     if markers is not None:
#
# File ~/.pyenv/versions/3.11.0/lib/python3.11/json/encoder.py:406, in _make_iterencode.<locals>._iterencode_dict(dct, _current_indent_level)
#     404         else:
#     405             chunks = _iterencode(value, _current_indent_level)
# --> 406         yield from chunks
#     407 if newline_indent is not None:
#     408     _current_indent_level -= 1
#
# File ~/.pyenv/versions/3.11.0/lib/python3.11/json/encoder.py:439, in _make_iterencode.<locals>._iterencode(o, _current_indent_level)
#     437         raise ValueError("Circular reference detected")
#     438     markers[markerid] = o
# --> 439 o = _default(o)
#     440 yield from _iterencode(o, _current_indent_level)
#     441 if markers is not None:
#
# File ~/.pyenv/versions/3.11.0/lib/python3.11/json/encoder.py:180, in JSONEncoder.default(self, o)
#     161 def default(self, o):
#     162     """Implement this method in a subclass such that it returns
#     163     a serializable object for ``o``, or calls the base implementation
#     164     (to raise a ``TypeError``).
#    (...)
#     178
#     179     """
# --> 180     raise TypeError(f'Object of type {o.__class__.__name__} '
#     181                     f'is not JSON serializable')
#
# TypeError: Object of type device is not JSON serializable
